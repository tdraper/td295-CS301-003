# %% [markdown]
# ## Basic Selection

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Selection in Series

# %%
ser = pd.Series([0, 1, 2, 3], index=['a', 'b', 'c', 'd'])
print(ser,"\n\n")
print("Item at index b is: ",ser['b'])

# %%
type(ser['b'])

# %%
ser

# %%
# Selecting within a range
ser['b':'d']

# %%
type(ser['b':'d'])

# %%
# Selecting by fancy index
ser[['b', 'a', 'd']]

# %%
ser

# %%
ser[ser%2!=0]

# %%
# Selecting by a Boolean masks
print("The series is:")
print(ser,'\n\n')
mask=ser%2!=0
print("The mask is:")
print(mask,'\n\n')
print("Output is:")
print(ser[mask])

# %%
ser[ser%2!=0]

# %%
ser[[False,True,False,True]]

# %% [markdown]
# **Assigning value to selection**

# %%
ser

# %%
ser['a']=10
ser

# %%
ser['b':'d'] = 5
ser

# %%
ser[ser%2==1]=0
ser

# %% [markdown]
# ### Selection in DataFrame

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict,index=['x','y','z'])
df

# %%
df['a']

# %%
df[['c', 'a']]

# %%
df['a']

# %%
i2 = df[['a','b']]
type(i2)

# %%
df['a'] > 5

# %%
mask=df['a'] > 5
print("mask is: ")
print(mask,'\n\n')
print("The dataframe is:")
print(df,'\n\n')
print("Output is:")
df[mask]

# %% [markdown]
# ## Selection with loc and iloc
# The main distinction between loc and iloc is: loc is label-based, which means that you have to specify rows and columns based on their row and column labels. iloc is integer position-based, so you have to specify rows and columns by their integer position values (0-based integer position).
#
# loc includes the upper range but iloc doesn't.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# https://towardsdatascience.com/how-to-use-loc-and-iloc-for-selecting-data-in-pandas-bd09cb4c3d79

# %% [markdown]
# [**pandas.DataFrame.iloc**](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.iloc.html)
#
# ```
# Purely integer-location based indexing for selection by position.
#
# .iloc[] is primarily integer position based (from 0 to length-1 of the axis), but may also be used with a boolean array.
#
# Allowed inputs are:
#
# An integer, e.g. 5.
#
# A list or array of integers, e.g. [4, 3, 0].
#
# A slice object with ints, e.g. 1:7.
#
# A boolean array.
#
# A callable function with one argument (the calling Series or DataFrame) and that returns valid output for indexing (one of the above). This is useful in method chains, when you don’t have a reference to the calling object, but would like to base your selection on some value.
#
# A tuple of row and column indexes. The tuple elements consist of one of the above inputs, e.g. (0, 1).
#
# .iloc will raise IndexError if a requested indexer is out-of-bounds, except slice indexers which allow out-of-bounds indexing (this conforms with python/numpy slice semantics).
# ```

# %%
mydict = [{'a': 1, 'b': 2, 'c': 3, 'd': 4},
          {'a': 100, 'b': 200, 'c': 300, 'd': 400},
          {'a': 1000, 'b': 2000, 'c': 3000, 'd': 4000 }]
df = pd.DataFrame(mydict,index=['x','y','z'])
df

# %% [markdown]
# ### Selection on rows

# %% [markdown]
# With a scalar integer.

# %%
df

# %%
df.iloc[0]

# %%
df.loc['x']

# %% [markdown]
# With a list of integers.

# %%
df.iloc[[0, 1]]

# %%
df.loc[['x', 'y']]

# %% [markdown]
# With a slice object.

# %%
df

# %%
df.iloc[0:3] # 0,1,2

# %%
# upper range is included
df.loc['x':'z'] # x,y,z

# %% [markdown]
#  With a boolean mask the same length as the index.

# %%
df.iloc[[True, False, True]]

# %%
df.loc[[True, False, True]]

# %% [markdown]
# ### Selection on rows and columns
# You can mix the indexer types for the index and columns. Use : to select the entire axis.

# %% [markdown]
# With scalar integers.

# %%
df

# %%
df.iloc[[0,1], [0,1]]

# %%
df.loc[['x','y'], ['a','b']]

# %% [markdown]
# With slice objects.

# %%
df

# %%
df.iloc[0:2, 0:2]
#df.iloc[[0,1], [0,1]]

# %%
df.loc['x':'y', 'a':'b']

# %% [markdown]
# With a boolean array whose length matches the columns.

# %%
df

# %%
df.iloc[[True, True, False], [True, True, False, False]]

# %%
df.loc[[True, True, False], [True, True, False, False]]

# %%
df

# %%
df.iloc[1,1]

# %%
df.loc['z','d']

# %% [markdown]
# ### Defaults

# %%
ser = pd.Series([0, 1, 2, 3], index=['a', 'b', 'c', 'd'])
ser

# %%
ser[2]

# %%
ser['c']

# %%
df['a']

# %%
df.iloc[:,0:3]
